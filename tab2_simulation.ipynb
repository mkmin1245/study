# %% [markdown]
# <a href="https://colab.research.google.com/github/mkmin1245/study/blob/main/tab2_simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

# %%
num = 1000
delta_x = 1.6

delta_y = 1.6


edge_x = np.random.uniform(-delta_x,0,size=num)
edge_y = np.random.uniform(-delta_y,0,size=num)

# %%
def cal_ab(x1,x2,y1,y2) :
  a = (y2-y1)/(x2-x1)
  b = (x2*y1-x1*y2)/(x2-x1)
  return a,b

# %%
a, b = cal_ab(edge_x,0, 0, edge_y)

# %%
mirror_x = (-2*a*b)/(a*a+1)
mirror_y = 2*b/(a*a+1)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np


plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 4)
plt.rcParams['font.size'] = 12

fig, ax = plt.subplots()

x1, x2, mx, y1, y2, my = edge_x, np.zeros(1000), mirror_x, np.zeros(1000), edge_y, mirror_y
ax.set(xlim=[-4, 1], ylim=[-4,1])

ax.add_patch(
     patches.Polygon(
         ((-4,0), (0,0), (0,-4), (-4,-4)),
         edgecolor = 'black',
         facecolor = 'lightgray',
         fill=True,
   ))


for i in range(1000):

  ax.add_patch(
     patches.Polygon(
         ((x1[i], y1[i]), (x2[i], y2[i]), (mx[i], my[i])),
         edgecolor = 'deeppink',
         facecolor = 'lightgray',
         fill=True,
   ))

mirrorpoint = ax.scatter(mx, my, color = "blue", s= 1, alpha = 0.1)
#mirrorpoint = ax.scatter(mirror_x, mirror_y)

plt.show()

# %%
fig, ax = plt.subplots()

mirrorpoint = ax.scatter(mx, my, color = "magenta", alpha = 0.01
                         )


plt.show()

# %%
for i in range(10):
  ax.add_patch(
     patches.Polygon(
         ((x1[i], y1[i]), (x2[i], y2[i]), (mx[i], my[i])),
         edgecolor = 'deeppink',
         facecolor = 'lightgray',
         fill=True,
   ))

mirrorpoint = ax.scatter(mirror_x, mirror_y)

plt.show()

# %%
x2.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-f6d503fcf291> in <cell line: 1>()
# ----> 1 x2.dtype
#
# AttributeError: 'int' object has no attribute 'dtype'

# %%
# prompt: make white canvas of 800*500 size with opencv

import numpy as np
import cv2

# Create a white canvas of size 800x500
canvas = np.zeros(shape=(600, 500, 3), dtype=np.uint8) + 255


for i in range (10):
  x1 = round(edge_x[i]*100)+400
  x2 = 400
  y1 = 100
  y2 = (-round(edge_y[i]*100))+100
  mx = round(mirror_x[i]*100)+400
  my = (-round(mirror_y[i]*100))+100
  #cv2.circle(canvas, (x1, y1), 5, (0,255,0), -1)
  #cv2.circle(canvas, (x2, y2), 5, (0,255,0), -1)
  cv2.circle(canvas, (mx, my), 5, (0,0,255), -1)

  cv2.line(canvas, (x1,y1), (x2,y2), R, 1)
  cv2.line(canvas, (mx, my), (x1,y1), B, 1)
  cv2.line(canvas, (mx, my), (x2,y2), B, 1)


# Display the canvas using OpenCV
cv2_imshow(canvas)
# Out:
# <PIL.Image.Image image mode=RGB size=500x600>

# %%
mx
# Out:
# -1

# %%
my
# Out:
# 0
